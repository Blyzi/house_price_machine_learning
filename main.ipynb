# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import geopandas as gpd
import requests

# %% [markdown]
# ### Import data

# %%
# df_2018 = pd.read_csv('data/data-2018.txt', sep='|')
# df_2019 = pd.read_csv('data/data-2019.txt', sep='|')
# df_2020 = pd.read_csv('data/data-2020.txt', sep='|')
# df_2021 = pd.read_csv('data/data-2021.txt', sep='|')
df_2022 = pd.read_csv('data/data-2022.txt', sep='|')
# Out:
# /var/folders/fw/2h3gl8xx695ctwssxd73bz5c0000gn/T/ipykernel_6728/2703567034.py:5: DtypeWarning: Columns (18,23,24,26,28,29,31,33,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_2022 = pd.read_csv('data/data-2022.txt', sep='|')

# %%
# df = pd.concat([df_2018, df_2019, df_2020, df_2021, df_2022])
df = df_2022

# %%
df.head(10)
# Out:
#    Identifiant de document  Reference document  1 Articles CGI
# 0                      NaN                 NaN             NaN  \
# 1                      NaN                 NaN             NaN
# 2                      NaN                 NaN             NaN
# 3                      NaN                 NaN             NaN
# 4                      NaN                 NaN             NaN
# 5                      NaN                 NaN             NaN
# 6                      NaN                 NaN             NaN
# 7                      NaN                 NaN             NaN
# 8                      NaN                 NaN             NaN
# 9                      NaN                 NaN             NaN
#
#    2 Articles CGI  3 Articles CGI  4 Articles CGI  5 Articles CGI
# 0             NaN             NaN             NaN             NaN  \
# 1             NaN             NaN             NaN             NaN
# 2             NaN             NaN             NaN             NaN
# ...

# %% [markdown]
# ### Data exploration

# %%
df.columns
# Out:
# Index(['Identifiant de document', 'Reference document', '1 Articles CGI',
#        '2 Articles CGI', '3 Articles CGI', '4 Articles CGI', '5 Articles CGI',
#        'No disposition', 'Date mutation', 'Nature mutation', 'Valeur fonciere',
#        'No voie', 'B/T/Q', 'Type de voie', 'Code voie', 'Voie', 'Code postal',
#        'Commune', 'Code departement', 'Code commune', 'Prefixe de section',
#        'Section', 'No plan', 'No Volume', '1er lot',
#        'Surface Carrez du 1er lot', '2eme lot', 'Surface Carrez du 2eme lot',
#        '3eme lot', 'Surface Carrez du 3eme lot', '4eme lot',
#        'Surface Carrez du 4eme lot', '5eme lot', 'Surface Carrez du 5eme lot',
#        'Nombre de lots', 'Code type local', 'Type local', 'Identifiant local',
#        'Surface reelle bati', 'Nombre pieces principales', 'Nature culture',
#        'Nature culture speciale', 'Surface terrain'],
#       dtype='object')

# %%
# Print the type of each column
df.dtypes
# Out:
# Identifiant de document       float64
# Reference document            float64
# 1 Articles CGI                float64
# 2 Articles CGI                float64
# 3 Articles CGI                float64
# 4 Articles CGI                float64
# 5 Articles CGI                float64
# No disposition                  int64
# Date mutation                  object
# Nature mutation                object
# Valeur fonciere                object
# No voie                       float64
# B/T/Q                          object
# Type de voie                   object
# Code voie                      object
# Voie                           object
# Code postal                   float64
# Commune                        object
# Code departement               object
# Code commune                    int64
# Prefixe de section            float64
# Section                        object
# No plan                         int64
# No Volume                      object
# 1er lot                        object
# ...

# %%
df.shape
# Out:
# (3803885, 43)

# %%
# Delete columns that are anonymous

df.drop(['Identifiant de document', 'Reference document', '1 Articles CGI',
       '2 Articles CGI', '3 Articles CGI', '4 Articles CGI', '5 Articles CGI', 'Identifiant local'], axis=1, inplace=True)

# %%
df.head(10)
# Out:
#    No disposition Date mutation Nature mutation Valeur fonciere  No voie
# 0               1    03/01/2022           Vente        55000,00     13.0  \
# 1               1    03/01/2022           Vente       143000,00      NaN
# 2               1    03/01/2022           Vente       143000,00      NaN
# 3               1    03/01/2022           Vente       143000,00     98.0
# 4               1    04/01/2022           Vente          300,00      NaN
# 5               1    06/01/2022           Vente       255000,00    282.0
# 6               1    06/01/2022           Vente       255000,00      NaN
# 7               1    03/01/2022           Vente       525000,00      NaN
# 8               1    03/01/2022           Vente       525000,00    217.0
# 9               1    03/01/2022           Vente       525000,00    217.0
#
#   B/T/Q Type de voie Code voie                 Voie  Code postal  ...
# 0   NaN          RUE      2280        DE LA LIBERTE       1000.0  ...  \
# ...

# %% [markdown]
# ### Data preparation

# %%
# Change the type of the columns

df['Date mutation'] = pd.to_datetime(df['Date mutation'], format='%d/%m/%Y')
df['Code postal'] = df['Code postal'].astype(str)
df['Code departement'] = df['Code departement'].astype(str)
df['Code commune'] = df['Code commune'].astype(str)
df['Valeur fonciere'] = df['Valeur fonciere'].replace(',', '.', regex=True).astype(float)

df.head(10)
# Out:
#    Identifiant de document  Reference document  1 Articles CGI
# 0                      NaN                 NaN             NaN  \
# 1                      NaN                 NaN             NaN
# 2                      NaN                 NaN             NaN
# 3                      NaN                 NaN             NaN
# 4                      NaN                 NaN             NaN
# 5                      NaN                 NaN             NaN
# 6                      NaN                 NaN             NaN
# 7                      NaN                 NaN             NaN
# 8                      NaN                 NaN             NaN
# 9                      NaN                 NaN             NaN
#
#    2 Articles CGI  3 Articles CGI  4 Articles CGI  5 Articles CGI
# 0             NaN             NaN             NaN             NaN  \
# 1             NaN             NaN             NaN             NaN
# 2             NaN             NaN             NaN             NaN
# ...

# %%
df.isnull().sum()
# Out:
# No disposition                      0
# Date mutation                       0
# Nature mutation                     0
# Valeur fonciere                 24721
# No voie                       1321227
# B/T/Q                         3627918
# Type de voie                  1406840
# Code voie                       39043
# Voie                            39153
# Code postal                         0
# Commune                             0
# Code departement                    0
# Code commune                        0
# Prefixe de section            3645046
# Section                           155
# No plan                             0
# No Volume                     3794976
# 1er lot                       2534572
# Surface Carrez du 1er lot     3436147
# 2eme lot                      3405819
# Surface Carrez du 2eme lot    3679945
# 3eme lot                      3732930
# Surface Carrez du 3eme lot    3790026
# 4eme lot                      3781161
# Surface Carrez du 4eme lot    3800533
# ...

# %%
df.duplicated().sum()
# Out:
# 269261

# %%
# Delete duplicate rows

df.drop_duplicates(inplace=True)
df.duplicated().sum()
# Out:
# 0

# %%
# Code INSEE

df['Code INSEE'] = df.apply(lambda x: x['Code departement'].rjust(2, '0') + x['Code commune'].rjust(3, '0'), axis=1)

# %%
# Use geopandas to get the coordinates of the communes

shapefile = 'communes/communes-20220101.shp'
gdf = gpd.read_file(shapefile)[['insee', 'geometry']]

gdf = gdf.merge(df, left_on='insee', right_on='Code INSEE', how='inner')

gdf.head(10)
# Out:
#    insee                                           geometry
# 0  2B222  POLYGON ((9.32017 42.38507, 9.32028 42.38510, ...  \
# 1  2B222  POLYGON ((9.32017 42.38507, 9.32028 42.38510, ...
# 2  2B222  POLYGON ((9.32017 42.38507, 9.32028 42.38510, ...
# 3  2B222  POLYGON ((9.32017 42.38507, 9.32028 42.38510, ...
# 4  2B222  POLYGON ((9.32017 42.38507, 9.32028 42.38510, ...
# 5  2B222  POLYGON ((9.32017 42.38507, 9.32028 42.38510, ...
# 6  2B222  POLYGON ((9.32017 42.38507, 9.32028 42.38510, ...
# 7  2B222  POLYGON ((9.32017 42.38507, 9.32028 42.38510, ...
# 8  2B222  POLYGON ((9.32017 42.38507, 9.32028 42.38510, ...
# 9  2B222  POLYGON ((9.32017 42.38507, 9.32028 42.38510, ...
#
#    Identifiant de document  Reference document  1 Articles CGI
# 0                      NaN                 NaN             NaN  \
# 1                      NaN                 NaN             NaN
# 2                      NaN                 NaN             NaN
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df[['Commune', 'Code INSEE', 'Population', 'Surface', 'geometry']].head(10)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/frame.py:3766, in DataFrame.__getitem__(self, key)
#    3764     if is_iterator(key):
#    3765         key = list(key)
# -> 3766     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3768 # take() does not accept boolean indexers
#    3769 if getattr(indexer, "dtype", None) == bool:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/indexes/base.py:5876, in Index._get_indexer_strict(self, key, axis_name)
#    5873 else:
#    5874     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5876 self._raise_if_missing(keyarr, indexer, axis_name)
# ...

# %% [markdown]
# ### Data Visualization

# %%
# Plot the price by department

df['1er lot']
# Out:
# 0          7.0
# 1          NaN
# 2          NaN
# 3          1.0
# 4          NaN
#           ...
# 3803880      3
# 3803881     49
# 3803882     49
# 3803883    244
# 3803884    516
# Name: 1er lot, Length: 3534625, dtype: object
